# %%
# imports
from dataset import SHREC2022Primitives
from networks import MinkowskiFCNN
import transforms as t
from losses import ConeLoss
from cone_fit import cone_fit, Cone
import MinkowskiEngine as ME

import torch
from torch.utils.data import DataLoader
from tqdm import tqdm
import os
import numpy as np
from utils import minkowski_collate, create_input_batch

import geomfitty
from geomfitty import geom3d
from geomfitty import plot
from geomfitty import fit3d
# configuration & hyperparameters
path = "/home/ioannis/Desktop/programming/data/SHREC/SHREC2022/dataset"
batch_size = 1
lr=1e-3
num_epochs = 100
eval_step = 1000000000
regression_targets = 7

checkpoint_path = "/home/ioannis/Desktop/programming/phd/SHREC/SHREC2022/checkpoints"
checkpoint_file = os.path.join(checkpoint_path, "cone_100.pth")

# %%
# Dataset and dataloader
train_transforms = [t.KeepInitialPoints(),
                    t.Translate(), 
                    t.SphereNormalization(), 
                    t.Initialization(),
                    t.RandomRotate(180, 0),
                    t.RandomRotate(180, 1),
                    t.RandomRotate(180, 2),
                    t.GaussianNoise(),
                    t.GetMean()]

valid_transforms = [t.KeepInitialPoints(),
                    t.Translate(), 
                    t.SphereNormalization(),
                    t.GetMean()]

t_dataset = SHREC2022Primitives(path, 
                                train=True, 
                                valid=False, 
                                valid_split=0.2, 
                                transform=train_transforms,
                                category="cone")

train_loader = DataLoader(t_dataset, 
                          batch_size=batch_size, 
                          shuffle=True, 
                          collate_fn=minkowski_collate, 
                         num_workers=8)

v_dataset = SHREC2022Primitives(path, 
                                train=True, 
                                valid=True, 
                                valid_split=0.2, 
                                transform=valid_transforms,
                                category="cone")

valid_loader = DataLoader(v_dataset, 
                          batch_size=batch_size, 
                          shuffle=False, 
                          collate_fn=minkowski_collate, 
                          num_workers=8)
# Out:
# Specified split already exists. Using the existing one.
# Specified split already exists. Using the existing one.

# %%
# network and device
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

net = MinkowskiFCNN(in_channel = 3, out_channel = regression_targets).to(device)
net.load_state_dict(torch.load(checkpoint_file))
net.eval()
# to use the "transform_cylinder_outputs" method
l = ConeLoss()
# Out:
# Using device: cuda:0

# %%
for i, sample in enumerate(valid_loader):
    print(f"Iteration: {i}")
    
    minknet_input = create_input_batch(
            sample, 
            device=device,
            quantization_size=0.05
        )

    gt = sample['labels'][:,1:].to(device)
    pred = net(minknet_input)
    theta, axis, vertex = l.transform_cone_outputs(pred, sample['trans'])
    
    theta = theta.detach().cpu().squeeze().numpy()
    axis   = axis.detach().cpu().squeeze().numpy()
    vertex = vertex.detach().cpu().squeeze().numpy()
    
    points = sample['initial_points'][0].numpy()
    
    #Calculating loss before optimization step
    init_a_loss, init_v_loss, init_t_loss = l(pred, gt, sample['trans'])
    init_loss = init_a_loss + init_v_loss + init_t_loss
    
    #Performing optimization step
    cone = Cone(theta, axis, vertex)
    print(cone.theta)
    cone = cone_fit(points, initial_guess=cone, weights=None)
    try:
        print(cone.theta)
    except:
        break
    theta, axis, vertex = torch.tensor([cone.theta]), torch.tensor(cone.axis), torch.tensor(cone.vertex)
    
    #Calculating loss after optimization step
    cone_params = torch.cat((theta, axis, vertex), dim=0).double().unsqueeze(0).to(device)
    a_loss, v_loss, t_loss = l(cone_params, gt.double(), None)
    final_loss = a_loss + v_loss + t_loss
    
    
    print("LOSS BEFORE OPTIMIZATION: ", init_loss.item())
    print("LOSS AFTER OPTIMIZATION: ", final_loss.item())
    print("IMPROVEMENT: ", init_loss.item() - final_loss.item())
# Out:
# Iteration: 0
# 0.8153984546661377
# 0.88959256693449
# LOSS BEFORE OPTIMIZATION:  0.05725323036313057
# LOSS AFTER OPTIMIZATION:  4.507418952413287e-16
# IMPROVEMENT:  0.05725323036313012
# Iteration: 1
# 0.7575044631958008
# 0.6304199307349779
# LOSS BEFORE OPTIMIZATION:  0.16795992851257324
# LOSS AFTER OPTIMIZATION:  4.3461391537743115e-16
# IMPROVEMENT:  0.1679599285125728
# Iteration: 2
# 0.8053709268569946
# 0.7719867189782142
# LOSS BEFORE OPTIMIZATION:  0.6763876080513
# LOSS AFTER OPTIMIZATION:  0.153767844650815
# IMPROVEMENT:  0.522619763400485
# Iteration: 3
# 0.8345319628715515
# 0.8633250713257149
# LOSS BEFORE OPTIMIZATION:  0.11112755537033081
# LOSS AFTER OPTIMIZATION:  1.6707717051971716e-16
# IMPROVEMENT:  0.11112755537033064
# Iteration: 4
# 0.6834679245948792
# 0.6952131085971137
# LOSS BEFORE OPTIMIZATION:  0.1807001382112503
# LOSS AFTER OPTIMIZATION:  6.901558587439122e-15
# IMPROVEMENT:  0.1807001382112434
# Iteration: 5
# 0.696857213973999
# 0.6452619470344679
# LOSS BEFORE OPTIMIZATION:  0.12755554914474487
# LOSS AFTER OPTIMIZATION:  0.0015517810904386226
# IMPROVEMENT:  0.12600376805430624
# Iteration: 6
# 0.772918701171875
# 1.5691240332896719
# LOSS BEFORE OPTIMIZATION:  0.593025803565979
# LOSS AFTER OPTIMIZATION:  1238.534543212442
# IMPROVEMENT:  -1237.941517408876
# Iteration: 7
# 0.8921828269958496
# 0.8878815023978938
# LOSS BEFORE OPTIMIZATION:  0.10930395871400833
# LOSS AFTER OPTIMIZATION:  0.0022023036757667326
# IMPROVEMENT:  0.1071016550382416
# Iteration: 8
# 0.765588641166687
# 0.5778848906187938
# LOSS BEFORE OPTIMIZATION:  0.10530959069728851
# LOSS AFTER OPTIMIZATION:  2.0585442424908572e-15
# IMPROVEMENT:  0.10530959069728646
# Iteration: 9
# 0.7804973125457764
# 0.691710758519436
# LOSS BEFORE OPTIMIZATION:  0.39048460125923157
# LOSS AFTER OPTIMIZATION:  9.686310672306457e-15
# IMPROVEMENT:  0.3904846012592219
# Iteration: 10
# 0.8476463556289673
# 0.901645632368869
# LOSS BEFORE OPTIMIZATION:  0.2505240738391876
# LOSS AFTER OPTIMIZATION:  0.0018312233358402186
# IMPROVEMENT:  0.2486928505033474
# Iteration: 11
# 0.6428357362747192
# 0.6041524341005191
# LOSS BEFORE OPTIMIZATION:  0.04850134253501892
# LOSS AFTER OPTIMIZATION:  5.482373121169046e-17
# IMPROVEMENT:  0.048501342535018865
# Iteration: 12
# 0.7844010591506958
# 0.9065412712810166
# LOSS BEFORE OPTIMIZATION:  0.09167463332414627
# LOSS AFTER OPTIMIZATION:  0.0029204441074390628
# IMPROVEMENT:  0.0887541892167072
# Iteration: 13
# 0.8580008149147034
# 0.863325072981109
# LOSS BEFORE OPTIMIZATION:  0.8789907693862915
# LOSS AFTER OPTIMIZATION:  4.0570464560090096e-16
# IMPROVEMENT:  0.8789907693862911
# Iteration: 14
# 0.7959654331207275
# 0.7057200954321996
# LOSS BEFORE OPTIMIZATION:  1.0956493616104126
# LOSS AFTER OPTIMIZATION:  1.502473454781424e-15
# IMPROVEMENT:  1.095649361610411
# Iteration: 15
# 0.6057776212692261
# 0.57403451426582
# LOSS BEFORE OPTIMIZATION:  0.10864128172397614
# LOSS AFTER OPTIMIZATION:  0.0007114826072088922
# IMPROVEMENT:  0.10792979911676724
# Iteration: 16
# 0.7067288160324097
# 0.7592423058704587
# LOSS BEFORE OPTIMIZATION:  0.18936817348003387
# LOSS AFTER OPTIMIZATION:  0.17774604171802227
# IMPROVEMENT:  0.0116221317620116
# Iteration: 17
# 0.8611178398132324
# 0.9274767907942271
# LOSS BEFORE OPTIMIZATION:  0.382705956697464
# LOSS AFTER OPTIMIZATION:  0.0034184321405086285
# IMPROVEMENT:  0.37928752455695536
# Iteration: 18
# 0.7498908042907715
# 0.677701431610099
# LOSS BEFORE OPTIMIZATION:  0.31595852971076965
# LOSS AFTER OPTIMIZATION:  6.463440941042128e-15
# IMPROVEMENT:  0.3159585297107632
# Iteration: 19
# 0.7430131435394287
# 1.1044295453842548
# LOSS BEFORE OPTIMIZATION:  0.8290307521820068
# LOSS AFTER OPTIMIZATION:  0.037780702659576136
# IMPROVEMENT:  0.7912500495224307
# Iteration: 20
# 0.766965389251709
# 0.8255381231870532
# LOSS BEFORE OPTIMIZATION:  0.08574385195970535
# LOSS AFTER OPTIMIZATION:  0.00022164415994846323
# IMPROVEMENT:  0.08552220779975689
# Iteration: 21
# 0.7725928425788879
# 0.6006500214615507
# LOSS BEFORE OPTIMIZATION:  1.4427226781845093
# LOSS AFTER OPTIMIZATION:  1.7161328824245109e-13
# IMPROVEMENT:  1.4427226781843376
# Iteration: 22
# 0.742615818977356
# 0.8440622315520415
# LOSS BEFORE OPTIMIZATION:  0.13699722290039062
# LOSS AFTER OPTIMIZATION:  2.2100661170928385e-15
# IMPROVEMENT:  0.1369972229003884
# Iteration: 23
# 0.7385265827178955
# 0.7039689222478149
# LOSS BEFORE OPTIMIZATION:  0.07095958292484283
# LOSS AFTER OPTIMIZATION:  1.158565944462312e-15
# IMPROVEMENT:  0.07095958292484168
# Iteration: 24
# 0.7004779577255249
# 0.7041328515960681
# LOSS BEFORE OPTIMIZATION:  0.2682541608810425
# LOSS AFTER OPTIMIZATION:  0.018669202275576044
# IMPROVEMENT:  0.24958495860546642
# Iteration: 25
# 0.7517484426498413
# 1.003418398303797
# LOSS BEFORE OPTIMIZATION:  0.6439272165298462
# LOSS AFTER OPTIMIZATION:  4.4267947038884084e-15
# IMPROVEMENT:  0.6439272165298418
# Iteration: 26
# 0.6904696226119995
# 0.5460159320919137
# LOSS BEFORE OPTIMIZATION:  0.189561665058136
# LOSS AFTER OPTIMIZATION:  1.397184889769898e-05
# IMPROVEMENT:  0.18954769320923828
# Iteration: 27
# 0.7947208285331726
# 0.5601979539844607
# LOSS BEFORE OPTIMIZATION:  0.6684924960136414
# LOSS AFTER OPTIMIZATION:  0.0001403432190893309
# IMPROVEMENT:  0.6683521527945521
# Iteration: 28
# 0.8217595815658569
# 0.7371097103854791
# LOSS BEFORE OPTIMIZATION:  0.11339345574378967
# LOSS AFTER OPTIMIZATION:  0.002511191690431323
# IMPROVEMENT:  0.11088226405335835
# Iteration: 29
# 0.7525114417076111
# 0.9080814571598026
# LOSS BEFORE OPTIMIZATION:  0.8892391324043274
# LOSS AFTER OPTIMIZATION:  0.3262102491346855
# IMPROVEMENT:  0.563028883269642
# Iteration: 30
# 0.8582829236984253
# 0.912402746423373
# LOSS BEFORE OPTIMIZATION:  0.03317701816558838
# LOSS AFTER OPTIMIZATION:  0.0016320733685061784
# IMPROVEMENT:  0.0315449447970822
# Iteration: 31
# 0.7394708395004272
# 0.8888448775945607
# LOSS BEFORE OPTIMIZATION:  0.7524121403694153
# LOSS AFTER OPTIMIZATION:  1.0598787285125084
# IMPROVEMENT:  -0.30746658814309313
# Iteration: 32
# 0.7777007818222046
# 0.8475645837885518
# LOSS BEFORE OPTIMIZATION:  0.17827937006950378
# LOSS AFTER OPTIMIZATION:  6.166755321536445e-15
# IMPROVEMENT:  0.17827937006949762
# Iteration: 33
# 0.7746932506561279
# 0.933371735573024
# LOSS BEFORE OPTIMIZATION:  0.39087069034576416
# LOSS AFTER OPTIMIZATION:  2.301065190631959e-15
# IMPROVEMENT:  0.3908706903457619
# Iteration: 34
# 0.6561800241470337
# 0.5551197730956318
# LOSS BEFORE OPTIMIZATION:  0.29919323325157166
# LOSS AFTER OPTIMIZATION:  4.819375291335822e-16
# IMPROVEMENT:  0.29919323325157116
# Iteration: 35
# 0.8159629702568054
# 0.8310915156368901
# LOSS BEFORE OPTIMIZATION:  0.117775097489357
# LOSS AFTER OPTIMIZATION:  0.021456114610471522
# IMPROVEMENT:  0.09631898287888548
# Iteration: 36
# 0.8238387703895569
# 0.9829079376302071
# LOSS BEFORE OPTIMIZATION:  0.06360112130641937
# LOSS AFTER OPTIMIZATION:  0.001308256832762713
# IMPROVEMENT:  0.06229286447365666
# Iteration: 37
# 0.7279961109161377
# 0.6216640973619796
# LOSS BEFORE OPTIMIZATION:  2.265064239501953
# LOSS AFTER OPTIMIZATION:  2.1917942710903134e-16
# IMPROVEMENT:  2.265064239501953
# Iteration: 38
# 0.7361887693405151
# 1.5693080800176866
# LOSS BEFORE OPTIMIZATION:  3.9503698348999023
# LOSS AFTER OPTIMIZATION:  3285.2201508308303
# IMPROVEMENT:  -3281.2697809959304
# Iteration: 39
# 0.7149316072463989
# 0.866827386389896
# LOSS BEFORE OPTIMIZATION:  2.5085251331329346
# LOSS AFTER OPTIMIZATION:  1.666221218164308e-14
# IMPROVEMENT:  2.5085251331329177
# Iteration: 40
# 0.7950806617736816
# 0.8730745292301929
# LOSS BEFORE OPTIMIZATION:  0.11473642289638519
# LOSS AFTER OPTIMIZATION:  0.001030786933097416
# IMPROVEMENT:  0.11370563596328778
# Iteration: 41
# 0.8321913480758667
# 0.4011770557402006
# LOSS BEFORE OPTIMIZATION:  0.30466288328170776
# LOSS AFTER OPTIMIZATION:  1.5242450851947191
# IMPROVEMENT:  -1.2195822019130114
# Iteration: 42
# 0.7073617577552795
# 0.8403872884655701
# LOSS BEFORE OPTIMIZATION:  0.8235516548156738
# LOSS AFTER OPTIMIZATION:  0.04772308050403056
# IMPROVEMENT:  0.7758285743116433
# Iteration: 43
# 0.7546325325965881
# 0.9991884756129144
# LOSS BEFORE OPTIMIZATION:  0.9483357667922974
# LOSS AFTER OPTIMIZATION:  0.0004521898887800057
# IMPROVEMENT:  0.9478835769035173
# Iteration: 44
# 0.7780325412750244
# 0.6806774132584215
# LOSS BEFORE OPTIMIZATION:  0.14354614913463593
# LOSS AFTER OPTIMIZATION:  0.0003201243395543992
# IMPROVEMENT:  0.14322602479508154
# Iteration: 45
# 0.7320727109909058
# 0.5506573718297885
# LOSS BEFORE OPTIMIZATION:  0.09907247126102448
# LOSS AFTER OPTIMIZATION:  0.24025079516396416
# IMPROVEMENT:  -0.1411783239029397
# Iteration: 46
# 0.7258140444755554
# 0.6354731741892503
# LOSS BEFORE OPTIMIZATION:  0.20997311174869537
# LOSS AFTER OPTIMIZATION:  0.0008636690297926723
# IMPROVEMENT:  0.2091094427189027
# Iteration: 47
# 0.7778702974319458
# 0.9500170213874621
# LOSS BEFORE OPTIMIZATION:  0.037407297641038895
# LOSS AFTER OPTIMIZATION:  0.05658526706090922
# IMPROVEMENT:  -0.019177969419870322
# Iteration: 48
# 0.7361711263656616
# 0.6324924750401728
# LOSS BEFORE OPTIMIZATION:  0.43823081254959106
# LOSS AFTER OPTIMIZATION:  0.03200951745069929
# IMPROVEMENT:  0.40622129509889177
# Iteration: 49
# 0.6954922676086426
# 1.0436952263420094
# LOSS BEFORE OPTIMIZATION:  1.279305100440979
# LOSS AFTER OPTIMIZATION:  2.6607304594302095e-14
# IMPROVEMENT:  1.2793051004409524
# Iteration: 50
# 0.7513407468795776
# 0.8772688420412519
# LOSS BEFORE OPTIMIZATION:  0.07941852509975433
# LOSS AFTER OPTIMIZATION:  0.0005323304329306689
# IMPROVEMENT:  0.07888619466682366
# Iteration: 51
# 0.7457627654075623
# 0.8230482408639728
# LOSS BEFORE OPTIMIZATION:  0.12903137505054474
# LOSS AFTER OPTIMIZATION:  4.419776479509425e-14
# IMPROVEMENT:  0.12903137505050055
# Iteration: 52
# 0.8556262254714966
# 0.9259553001486891
# LOSS BEFORE OPTIMIZATION:  0.1144278272986412
# LOSS AFTER OPTIMIZATION:  0.15480049105558674
# IMPROVEMENT:  -0.04037266375694554
# Iteration: 53
# 0.8008159399032593
# 0.9771890363521684
# LOSS BEFORE OPTIMIZATION:  0.9983121156692505
# LOSS AFTER OPTIMIZATION:  0.016784411426401795
# IMPROVEMENT:  0.9815277042428487
# Iteration: 54
# 0.7875875234603882
# 1.0226812299666623
# LOSS BEFORE OPTIMIZATION:  0.4344616234302521
# LOSS AFTER OPTIMIZATION:  8.676336811465348e-16
# IMPROVEMENT:  0.4344616234302512
# Iteration: 55
# 0.8667980432510376
# 0.9407073499527542
# LOSS BEFORE OPTIMIZATION:  0.27899959683418274
# LOSS AFTER OPTIMIZATION:  5.114056635868236e-06
# IMPROVEMENT:  0.27899448277754685
# Iteration: 56
# 0.7385523319244385
# 0.9906624186072976
# LOSS BEFORE OPTIMIZATION:  0.11284102499485016
# LOSS AFTER OPTIMIZATION:  0.010493340984958998
# IMPROVEMENT:  0.10234768400989117
# Iteration: 57
# 0.7869651913642883
# 0.8799065426074373
# LOSS BEFORE OPTIMIZATION:  0.18818816542625427
# LOSS AFTER OPTIMIZATION:  0.0010214432922521044
# IMPROVEMENT:  0.18716672213400218
# Iteration: 58
# 0.7393457889556885
# 0.8913437803601172
# LOSS BEFORE OPTIMIZATION:  0.9482362270355225
# LOSS AFTER OPTIMIZATION:  5.313466020725385e-14
# IMPROVEMENT:  0.9482362270354693
# Iteration: 59
# 0.7807407975196838
# 0.8025394862391664
# LOSS BEFORE OPTIMIZATION:  0.32636240124702454
# LOSS AFTER OPTIMIZATION:  0.0067824168670133165
# IMPROVEMENT:  0.31957998438001123
# Iteration: 60
# 0.8699671626091003
# 1.0534687156662728
# LOSS BEFORE OPTIMIZATION:  0.05806390941143036
# LOSS AFTER OPTIMIZATION:  0.0525586025463225
# IMPROVEMENT:  0.005505306865107862
# Iteration: 61
# 0.6734440922737122
# 1.561496295338199
# LOSS BEFORE OPTIMIZATION:  0.6623438596725464
# LOSS AFTER OPTIMIZATION:  251.64023134078093
# IMPROVEMENT:  -250.97788748110838
# Iteration: 62
# 0.7745559215545654
# 1.562406941274286
# LOSS BEFORE OPTIMIZATION:  0.4795305132865906
# LOSS AFTER OPTIMIZATION:  4.363783328978395
# IMPROVEMENT:  -3.884252815691805
# Iteration: 63
# 0.805029034614563
# 1.568376816741421
# LOSS BEFORE OPTIMIZATION:  1.283745527267456
# LOSS AFTER OPTIMIZATION:  973.9546620027061
# IMPROVEMENT:  -972.6709164754386
# Iteration: 64
# 0.903387188911438
# 0.8900921699545192
# LOSS BEFORE OPTIMIZATION:  0.011731542646884918
# LOSS AFTER OPTIMIZATION:  7.415305224054734e-05
# IMPROVEMENT:  0.01165738959464437
# Iteration: 65
# 0.744454562664032
# 0.751971442699481
# LOSS BEFORE OPTIMIZATION:  0.22544977068901062
# LOSS AFTER OPTIMIZATION:  0.0025603501730343337
# IMPROVEMENT:  0.2228894205159763
# Iteration: 66
# 0.8844724893569946
# 1.04719754074009
# LOSS BEFORE OPTIMIZATION:  0.20916666090488434
# LOSS AFTER OPTIMIZATION:  1.6476015818586403e-14
# IMPROVEMENT:  0.20916666090486785
# Iteration: 67
# 0.8078592419624329
# 0.7915272473438308
# LOSS BEFORE OPTIMIZATION:  0.06667128205299377
# LOSS AFTER OPTIMIZATION:  3.06577723691196e-14
# IMPROVEMENT:  0.06667128205296312
# Iteration: 68
# 0.8430181741714478
# 0.6051140858040726
# LOSS BEFORE OPTIMIZATION:  0.8612355589866638
# LOSS AFTER OPTIMIZATION:  0.1577094891447102
# IMPROVEMENT:  0.7035260698419536
# Iteration: 69
# 0.7088876962661743
# 1.3930519063969937
# LOSS BEFORE OPTIMIZATION:  3.5994157791137695
# LOSS AFTER OPTIMIZATION:  4.461834378968586
# IMPROVEMENT:  -0.8624185998548164
# Iteration: 70
# 0.7805083990097046
# 0.5825331344482823
# LOSS BEFORE OPTIMIZATION:  0.22220277786254883
# LOSS AFTER OPTIMIZATION:  0.07823394472362909
# IMPROVEMENT:  0.14396883313891973
# Iteration: 71
# 0.7451229095458984
# 0.5374451759582136
# LOSS BEFORE OPTIMIZATION:  1.8718681335449219
# LOSS AFTER OPTIMIZATION:  0.4038060059378381
# IMPROVEMENT:  1.4680621276070838
# Iteration: 72
# 0.6652178764343262
# 0.5673779329823501
# LOSS BEFORE OPTIMIZATION:  1.469797968864441
# LOSS AFTER OPTIMIZATION:  1.079746861171311e-15
# IMPROVEMENT:  1.4697979688644398
# Iteration: 73
# 0.7912020683288574
# 1.2928864647918996
# LOSS BEFORE OPTIMIZATION:  1.8819252252578735
# LOSS AFTER OPTIMIZATION:  4.341298413840956
# IMPROVEMENT:  -2.4593731885830827
# Iteration: 74
# 0.7035737037658691
# 1.5651626383193602
# LOSS BEFORE OPTIMIZATION:  0.4004221558570862
# LOSS AFTER OPTIMIZATION:  3.2112253829338546
# IMPROVEMENT:  -2.8108032270767684
# Iteration: 75
# 0.73491370677948
# 0.7385376397039515
# LOSS BEFORE OPTIMIZATION:  0.24003800749778748
# LOSS AFTER OPTIMIZATION:  2.4303735661146385e-05
# IMPROVEMENT:  0.24001370376212633
# Iteration: 76
# 0.8396824598312378
# 0.8791610825624391
# LOSS BEFORE OPTIMIZATION:  0.05231563001871109
# LOSS AFTER OPTIMIZATION:  1.8960130775571023e-06
# IMPROVEMENT:  0.052313734005633536
# Iteration: 77
# 0.7043824195861816
# 0.6558405291564241
# LOSS BEFORE OPTIMIZATION:  0.10947035998106003
# LOSS AFTER OPTIMIZATION:  0.0050252333172276864
# IMPROVEMENT:  0.10444512666383234
# Iteration: 78
# 0.6804360151290894
# 0.694536802824942
# LOSS BEFORE OPTIMIZATION:  0.03705664724111557
# LOSS AFTER OPTIMIZATION:  0.2105429919903352
# IMPROVEMENT:  -0.17348634474921962
# Iteration: 79
# 0.6972978115081787
# 1.568379804822574
# LOSS BEFORE OPTIMIZATION:  0.5110215544700623
# LOSS AFTER OPTIMIZATION:  1717.3072550178147
# IMPROVEMENT:  -1716.7962334633446
# Iteration: 80
# 0.6560877561569214
# 0.5359724017650712
# LOSS BEFORE OPTIMIZATION:  0.11439404636621475
# LOSS AFTER OPTIMIZATION:  0.0036000676067372036
# IMPROVEMENT:  0.11079397875947755
# Iteration: 81
# 0.7928104400634766
# 0.8391095409531304
# LOSS BEFORE OPTIMIZATION:  0.08455736935138702
# LOSS AFTER OPTIMIZATION:  0.0020392164379021112
# IMPROVEMENT:  0.08251815291348491
# Iteration: 82
# 0.7254953384399414
# 0.7092224230761581
# LOSS BEFORE OPTIMIZATION:  0.2844453454017639
# LOSS AFTER OPTIMIZATION:  1.1885576732175379e-14
# IMPROVEMENT:  0.28444534540175204
# Iteration: 83
# 0.7664663791656494
# 0.8666277072431908
# LOSS BEFORE OPTIMIZATION:  0.11408329010009766
# LOSS AFTER OPTIMIZATION:  0.07924375579759453
# IMPROVEMENT:  0.034839534302503125
# Iteration: 84
# 0.8290395736694336
# 0.8357128927565921
# LOSS BEFORE OPTIMIZATION:  0.0890733152627945
# LOSS AFTER OPTIMIZATION:  0.001016186462674433
# IMPROVEMENT:  0.08805712880012007
# Iteration: 85
# 0.7970016598701477
# 0.8241078775284659
# LOSS BEFORE OPTIMIZATION:  0.7547873854637146
# LOSS AFTER OPTIMIZATION:  0.00011437905725425648
# IMPROVEMENT:  0.7546730064064603
# Iteration: 86
# 0.7995951175689697
# 0.9498128301791701
# LOSS BEFORE OPTIMIZATION:  0.22387248277664185
# LOSS AFTER OPTIMIZATION:  0.6763494369561956
# IMPROVEMENT:  -0.4524769541795538
# Iteration: 87
# 0.6990594863891602
# 0.8481364731138581
# LOSS BEFORE OPTIMIZATION:  0.10779760777950287
# LOSS AFTER OPTIMIZATION:  0.49680410252254936
# IMPROVEMENT:  -0.3890064947430465
# Iteration: 88
# 0.7667366862297058
# 0.6677959125253653
# LOSS BEFORE OPTIMIZATION:  0.9837708473205566
# LOSS AFTER OPTIMIZATION:  0.00565781534025928
# IMPROVEMENT:  0.9781130319802973
# Iteration: 89
# 0.8548545837402344
# 0.9158600651939666
# LOSS BEFORE OPTIMIZATION:  0.14019586145877838
# LOSS AFTER OPTIMIZATION:  9.989245816148881e-17
# IMPROVEMENT:  0.14019586145877827
# Iteration: 90
# 0.823136568069458
# 1.0139253818298877
# LOSS BEFORE OPTIMIZATION:  0.5227724313735962
# LOSS AFTER OPTIMIZATION:  9.810746271286666e-15
# IMPROVEMENT:  0.5227724313735864
# Iteration: 91
# 0.8753156661987305
# 0.9251552064795897
# LOSS BEFORE OPTIMIZATION:  0.12786370515823364
# LOSS AFTER OPTIMIZATION:  0.0010285060734049143
# IMPROVEMENT:  0.12683519908482874
# Iteration: 92
# 0.691015362739563
# 0.6812037546662584
# LOSS BEFORE OPTIMIZATION:  0.08922440558671951
# LOSS AFTER OPTIMIZATION:  1.053813466865626e-15
# IMPROVEMENT:  0.08922440558671846
# Iteration: 93
# 0.7861285209655762
# 0.7582550838430312
# LOSS BEFORE OPTIMIZATION:  0.007209984585642815
# LOSS AFTER OPTIMIZATION:  1.7532124505343916e-15
# IMPROVEMENT:  0.007209984585641062
# Iteration: 94
# 0.6371356248855591
# 0.6674401930418901
# LOSS BEFORE OPTIMIZATION:  0.12011421471834183
# LOSS AFTER OPTIMIZATION:  0.0008073250914123667
# IMPROVEMENT:  0.11930688962692947
# Iteration: 95
# 0.7432821393013
# 0.5495328191596421
# LOSS BEFORE OPTIMIZATION:  0.4002663493156433
# LOSS AFTER OPTIMIZATION:  0.00051778107353635
# IMPROVEMENT:  0.39974856824210697
# Iteration: 96
# 0.7802945375442505
# 1.000535751762639
# LOSS BEFORE OPTIMIZATION:  1.4595601558685303
# LOSS AFTER OPTIMIZATION:  0.027372793714958578
# IMPROVEMENT:  1.4321873621535717
# Iteration: 97
# 0.8393027782440186
# 1.005292450515654
# LOSS BEFORE OPTIMIZATION:  0.17613251507282257
# LOSS AFTER OPTIMIZATION:  0.02075909131016258
# IMPROVEMENT:  0.15537342376266
# Iteration: 98
# 0.6794394254684448
# 0.6437462252909657
# LOSS BEFORE OPTIMIZATION:  0.06585343927145004
# LOSS AFTER OPTIMIZATION:  0.005918368734045871
# IMPROVEMENT:  0.05993507053740417
# Iteration: 99
# 0.7752371430397034
# 0.6619409656006459
# LOSS BEFORE OPTIMIZATION:  2.034926414489746
# LOSS AFTER OPTIMIZATION:  5.229636786644623e-14
# IMPROVEMENT:  2.0349264144896937
# Iteration: 100
# 0.7043266296386719
# 0.8790855409638518
# LOSS BEFORE OPTIMIZATION:  3.303422212600708
# LOSS AFTER OPTIMIZATION:  3.888335044526703e-14
# IMPROVEMENT:  3.303422212600669
# Iteration: 101
# 0.8222354650497437
# 1.0191789052455733
# LOSS BEFORE OPTIMIZATION:  1.159048318862915
# LOSS AFTER OPTIMIZATION:  3.64875511046914e-15
# IMPROVEMENT:  1.1590483188629115
# Iteration: 102
# 0.6740112900733948
# 0.061019005809543427
# LOSS BEFORE OPTIMIZATION:  1.2052804231643677
# LOSS AFTER OPTIMIZATION:  861.1378709699082
# IMPROVEMENT:  -859.9325905467439
# Iteration: 103
# 0.7375665307044983
# 1.0389321705010757
# LOSS BEFORE OPTIMIZATION:  0.21592555940151215
# LOSS AFTER OPTIMIZATION:  0.00724134446700377
# IMPROVEMENT:  0.20868421493450837
# Iteration: 104
# 0.7359771728515625
# 0.7775179104418647
# LOSS BEFORE OPTIMIZATION:  0.023534197360277176
# LOSS AFTER OPTIMIZATION:  1.0817222087918726e-14
# IMPROVEMENT:  0.023534197360266358
# Iteration: 105
# 0.9016728401184082
# 1.0471975486126883
# LOSS BEFORE OPTIMIZATION:  0.31133273243904114
# LOSS AFTER OPTIMIZATION:  2.7155010198216487e-14
# IMPROVEMENT:  0.311332732439014
# Iteration: 106
# 0.7411717176437378
# 0.9753997381197271
# LOSS BEFORE OPTIMIZATION:  2.2790937423706055
# LOSS AFTER OPTIMIZATION:  3.017858880905327e-14
# IMPROVEMENT:  2.2790937423705753
# Iteration: 107
# 0.713223397731781
# 0.8186875353531757
# LOSS BEFORE OPTIMIZATION:  0.9317531585693359
# LOSS AFTER OPTIMIZATION:  0.5841015345035652
# IMPROVEMENT:  0.34765162406577077
# Iteration: 108
# 0.7767177820205688
# 0.5411105435096211
# LOSS BEFORE OPTIMIZATION:  0.6076165437698364
# LOSS AFTER OPTIMIZATION:  5.658802283189017e-13
# IMPROVEMENT:  0.6076165437692705
# Iteration: 109
# 0.8252984285354614
# 0.9028780326976518
# LOSS BEFORE OPTIMIZATION:  0.08898407965898514
# LOSS AFTER OPTIMIZATION:  6.888710811366581e-05
# IMPROVEMENT:  0.08891519255087148
# Iteration: 110
# 0.7866833209991455
# 0.9619239287927133
# LOSS BEFORE OPTIMIZATION:  0.2549216151237488
# LOSS AFTER OPTIMIZATION:  0.01866688908546677
# IMPROVEMENT:  0.23625472603828201
# Iteration: 111
# 0.8369914293289185
# 0.949132228795855
# LOSS BEFORE OPTIMIZATION:  0.05772092193365097
# LOSS AFTER OPTIMIZATION:  9.219404010289147e-15
# IMPROVEMENT:  0.05772092193364175
# Iteration: 112
# 0.8161221742630005
# 0.7845961341552764
# LOSS BEFORE OPTIMIZATION:  0.6546266674995422
# LOSS AFTER OPTIMIZATION:  0.10390854031617258
# IMPROVEMENT:  0.5507181271833697
# Iteration: 113
# 0.8604377508163452
# 0.7950295738634711
# LOSS BEFORE OPTIMIZATION:  0.3161211609840393
# LOSS AFTER OPTIMIZATION:  2.1266768442178962e-14
# IMPROVEMENT:  0.31612116098401805
# Iteration: 114
# 0.832215428352356
# 0.8983484020079368
# LOSS BEFORE OPTIMIZATION:  0.26731547713279724
# LOSS AFTER OPTIMIZATION:  1.5488109500887785e-16
# IMPROVEMENT:  0.2673154771327971
# Iteration: 115
# 0.7993429899215698
# 0.6059036203113987
# LOSS BEFORE OPTIMIZATION:  0.85768723487854
# LOSS AFTER OPTIMIZATION:  6.385997457104406e-14
# IMPROVEMENT:  0.8576872348784762
# Iteration: 116
# 0.662309467792511
# 0.5163048945572747
# LOSS BEFORE OPTIMIZATION:  0.16634808480739594
# LOSS AFTER OPTIMIZATION:  0.050236715102551996
# IMPROVEMENT:  0.11611136970484394
# Iteration: 117
# 0.8027025461196899
# 0.7428292670127303
# LOSS BEFORE OPTIMIZATION:  0.2094704508781433
# LOSS AFTER OPTIMIZATION:  0.0021262055462424054
# IMPROVEMENT:  0.2073442453319009
# Iteration: 118
# 0.7797778248786926
# 0.8491106408722178
# LOSS BEFORE OPTIMIZATION:  0.11274615675210953
# LOSS AFTER OPTIMIZATION:  0.013691949863279701
# IMPROVEMENT:  0.09905420688882982
# Iteration: 119
# 0.7550164461135864
# 0.7293221962127359
# LOSS BEFORE OPTIMIZATION:  0.14841128885746002
# LOSS AFTER OPTIMIZATION:  0.05988284846823465
# IMPROVEMENT:  0.08852844038922537
# Iteration: 120
# 0.8571659326553345
# 0.8858665887968389
# LOSS BEFORE OPTIMIZATION:  0.09070798754692078
# LOSS AFTER OPTIMIZATION:  0.015157948978658794
# IMPROVEMENT:  0.07555003856826198
# Iteration: 121
# 0.7268561124801636
# 0.9260790494197411
# LOSS BEFORE OPTIMIZATION:  0.19690649211406708
# LOSS AFTER OPTIMIZATION:  0.2612791572918696
# IMPROVEMENT:  -0.06437266517780255
# Iteration: 122
# 0.720685601234436
# 0.6829549282136369
# LOSS BEFORE OPTIMIZATION:  0.036249250173568726
# LOSS AFTER OPTIMIZATION:  5.582726736548692e-16
# IMPROVEMENT:  0.03624925017356817
# Iteration: 123
# 0.876490592956543
# 0.8987382140646496
# LOSS BEFORE OPTIMIZATION:  0.015942974016070366
# LOSS AFTER OPTIMIZATION:  0.09113684951862148
# IMPROVEMENT:  -0.07519387550255112
# Iteration: 124
# 0.8372932076454163
# 0.8822384057850423
# LOSS BEFORE OPTIMIZATION:  0.05817089229822159
# LOSS AFTER OPTIMIZATION:  0.006520169223144576
# IMPROVEMENT:  0.05165072307507701
# Iteration: 125
# 0.8687546253204346
# 0.6330862305928873
# LOSS BEFORE OPTIMIZATION:  0.35042646527290344
# LOSS AFTER OPTIMIZATION:  0.00012375209154145633
# IMPROVEMENT:  0.35030271318136197
# Iteration: 126
# 0.739337682723999
# 0.8906268787539847
# LOSS BEFORE OPTIMIZATION:  0.32684236764907837
# LOSS AFTER OPTIMIZATION:  0.10426450843941443
# IMPROVEMENT:  0.22257785920966394
# Iteration: 127
# 0.5458705425262451
# 0.5240676890920591
# LOSS BEFORE OPTIMIZATION:  0.025929782539606094
# LOSS AFTER OPTIMIZATION:  0.0004220648584584677
# IMPROVEMENT:  0.025507717681147627
# Iteration: 128
# 0.7965569496154785
# 0.7023027659050468
# LOSS BEFORE OPTIMIZATION:  0.38238856196403503
# LOSS AFTER OPTIMIZATION:  5.1585136666966465e-06
# IMPROVEMENT:  0.38238340345036836
# Iteration: 129
# 0.7247231602668762
# 0.6166839497739582
# LOSS BEFORE OPTIMIZATION:  0.43810418248176575
# LOSS AFTER OPTIMIZATION:  0.023607549630163923
# IMPROVEMENT:  0.4144966328516018
# Iteration: 130
# 0.8292818069458008
# 0.9789020582538358
# LOSS BEFORE OPTIMIZATION:  0.05298963934183121
# LOSS AFTER OPTIMIZATION:  2.9074057095549694e-16
# IMPROVEMENT:  0.052989639341830916
# Iteration: 131
# 0.6965700387954712
# 0.5878753592969879
# LOSS BEFORE OPTIMIZATION:  0.15110908448696136
# LOSS AFTER OPTIMIZATION:  0.006318212718829229
# IMPROVEMENT:  0.14479087176813213
# Iteration: 132
# 0.8069016337394714
# 0.6196169279562594
# LOSS BEFORE OPTIMIZATION:  0.44679802656173706
# LOSS AFTER OPTIMIZATION:  0.40290028853724635
# IMPROVEMENT:  0.04389773802449071
# Iteration: 133
# 0.8656153678894043
# 0.942127565235129
# LOSS BEFORE OPTIMIZATION:  0.0263415165245533
# LOSS AFTER OPTIMIZATION:  4.806159526096305e-16
# IMPROVEMENT:  0.026341516524552817
# Iteration: 134
# 0.668931782245636
# 0.6970581455371855
# LOSS BEFORE OPTIMIZATION:  0.07701616734266281
# LOSS AFTER OPTIMIZATION:  0.002294112106035547
# IMPROVEMENT:  0.07472205523662727
# Iteration: 135
# 0.6961612105369568
# 0.6904256034110943
# LOSS BEFORE OPTIMIZATION:  0.0689338967204094
# LOSS AFTER OPTIMIZATION:  0.0020836857571710585
# IMPROVEMENT:  0.06685021096323833
# Iteration: 136
# 0.80069899559021
# 0.8271445450824728
# LOSS BEFORE OPTIMIZATION:  0.3368779718875885
# LOSS AFTER OPTIMIZATION:  0.0035282892139897417
# IMPROVEMENT:  0.33334968267359877
# Iteration: 137
# 0.7641192078590393
# 0.8584147970919287
# LOSS BEFORE OPTIMIZATION:  0.2537737786769867
# LOSS AFTER OPTIMIZATION:  0.08395788693910251
# IMPROVEMENT:  0.1698158917378842
# Iteration: 138
# 0.7584514617919922
# 0.7317202458012071
# LOSS BEFORE OPTIMIZATION:  0.1226748526096344
# LOSS AFTER OPTIMIZATION:  0.013592041945909182
# IMPROVEMENT:  0.10908281066372522
# Iteration: 139
# 0.7984374761581421
# 0.7472088303198713
# LOSS BEFORE OPTIMIZATION:  1.177230954170227
# LOSS AFTER OPTIMIZATION:  0.02538594323922442
# IMPROVEMENT:  1.1518450109310026
# Iteration: 140
# 0.9053817987442017
# 0.9841555580057547
# LOSS BEFORE OPTIMIZATION:  0.028310418128967285
# LOSS AFTER OPTIMIZATION:  2.2128472001953245e-14
# IMPROVEMENT:  0.028310418128945157
# Iteration: 141
# 0.6850854754447937
# 0.6409269385344563
# LOSS BEFORE OPTIMIZATION:  0.553478479385376
# LOSS AFTER OPTIMIZATION:  1.510437464240664e-14
# IMPROVEMENT:  0.5534784793853609
# Iteration: 142
# 0.8167600631713867
# 0.8902628133369229
# LOSS BEFORE OPTIMIZATION:  0.23710107803344727
# LOSS AFTER OPTIMIZATION:  0.0018402802358818962
# IMPROVEMENT:  0.23526079779756537
# Iteration: 143
# 0.7552275061607361
# 0.6864572671110892
# LOSS BEFORE OPTIMIZATION:  0.15893618762493134
# LOSS AFTER OPTIMIZATION:  3.4907122839600615e-15
# IMPROVEMENT:  0.15893618762492784
# Iteration: 144
# 0.8204816579818726
# 0.6919994216687608
# LOSS BEFORE OPTIMIZATION:  0.5017104744911194
# LOSS AFTER OPTIMIZATION:  0.001232468160896242
# IMPROVEMENT:  0.5004780063302231
# Iteration: 145
# 0.8678835034370422
# 0.9782450088655309
# LOSS BEFORE OPTIMIZATION:  0.29714536666870117
# LOSS AFTER OPTIMIZATION:  0.00034253721832433346
# IMPROVEMENT:  0.29680282945037684
# Iteration: 146
# 0.603639543056488
# 0.5736946727587996
# LOSS BEFORE OPTIMIZATION:  0.06052420660853386
# LOSS AFTER OPTIMIZATION:  0.001384310548799614
# IMPROVEMENT:  0.05913989605973424
# Iteration: 147
# 0.7403577566146851
# 0.7760111142724011
# LOSS BEFORE OPTIMIZATION:  0.2640165388584137
# LOSS AFTER OPTIMIZATION:  0.004401539457467825
# IMPROVEMENT:  0.25961499940094585
# Iteration: 148
# 0.815762460231781
# 0.8757575264915133
# LOSS BEFORE OPTIMIZATION:  0.0085153104737401
# LOSS AFTER OPTIMIZATION:  4.983107112716357e-05
# IMPROVEMENT:  0.008465479402612937
# Iteration: 149
# 0.8002519607543945
# 0.874599142382193
# LOSS BEFORE OPTIMIZATION:  0.40641212463378906
# LOSS AFTER OPTIMIZATION:  0.01374778221862674
# IMPROVEMENT:  0.39266434241516235
# Iteration: 150
# 0.7879856824874878
# 1.0471975702289258
# LOSS BEFORE OPTIMIZATION:  1.4817827939987183
# LOSS AFTER OPTIMIZATION:  5.1429789030340867e-14
# IMPROVEMENT:  1.4817827939986667
# Iteration: 151
# 0.8208606839179993
# 0.8423111250843301
# LOSS BEFORE OPTIMIZATION:  0.16167765855789185
# LOSS AFTER OPTIMIZATION:  7.701397817561331e-14
# IMPROVEMENT:  0.16167765855781482
# Iteration: 152
# 0.755135715007782
# 0.9505524758130781
# LOSS BEFORE OPTIMIZATION:  0.503424882888794
# LOSS AFTER OPTIMIZATION:  0.025463142497807408
# IMPROVEMENT:  0.47796174039098654
# Iteration: 153
# 0.8904504776000977
# 1.0349086737187454
# LOSS BEFORE OPTIMIZATION:  0.49135857820510864
# LOSS AFTER OPTIMIZATION:  0.000988339445946613
# IMPROVEMENT:  0.490370238759162
# Iteration: 154
# 0.7979453206062317
# 0.6041522963317255
# LOSS BEFORE OPTIMIZATION:  1.1866745948791504
# LOSS AFTER OPTIMIZATION:  2.3090584422624833e-13
# IMPROVEMENT:  1.1866745948789195
# Iteration: 155
# 0.8019299507141113
# 0.747463044895012
# LOSS BEFORE OPTIMIZATION:  0.4439208209514618
# LOSS AFTER OPTIMIZATION:  0.02543179573328283
# IMPROVEMENT:  0.418489025218179
# Iteration: 156
# 0.7551021575927734
# 0.6149384075450531
# LOSS BEFORE OPTIMIZATION:  0.8187843561172485
# LOSS AFTER OPTIMIZATION:  0.0001999196467458886
# IMPROVEMENT:  0.8185844364705026
# Iteration: 157
# 0.7778042554855347
# 0.8384949151185299
# LOSS BEFORE OPTIMIZATION:  0.5558702349662781
# LOSS AFTER OPTIMIZATION:  0.001978054523125968
# IMPROVEMENT:  0.5538921804431521
# Iteration: 158
# 0.7127283215522766
# 0.9735716907961405
# LOSS BEFORE OPTIMIZATION:  1.3298836946487427
# LOSS AFTER OPTIMIZATION:  0.06875170379830728
# IMPROVEMENT:  1.2611319908504355
# Iteration: 159
# 0.8578034043312073
# 1.0252589022660572
# LOSS BEFORE OPTIMIZATION:  0.2771781086921692
# LOSS AFTER OPTIMIZATION:  0.002868220890052332
# IMPROVEMENT:  0.27430988780211685
# Iteration: 160
# 0.7786649465560913
# 1.0435686319236794
# LOSS BEFORE OPTIMIZATION:  8.244948387145996
# LOSS AFTER OPTIMIZATION:  0.07033627526611366
# IMPROVEMENT:  8.174612111879883
# Iteration: 161
# 0.7923059463500977
# 1.5582380160039493
# LOSS BEFORE OPTIMIZATION:  0.12601369619369507
# LOSS AFTER OPTIMIZATION:  123.29498271287004
# IMPROVEMENT:  -123.16896901667634
# Iteration: 162
# 0.8417085409164429
# 0.7670109241677625
# LOSS BEFORE OPTIMIZATION:  2.8277950286865234
# LOSS AFTER OPTIMIZATION:  2.466129157920466e-14
# IMPROVEMENT:  2.8277950286864986
# Iteration: 163
# 0.8059029579162598
# 0.8545692635258356
# LOSS BEFORE OPTIMIZATION:  0.04724160581827164
# LOSS AFTER OPTIMIZATION:  2.784970047941561e-14
# IMPROVEMENT:  0.047241605818243784
# Iteration: 164
# 0.7165887951850891
# 0.6342914620117189
# LOSS BEFORE OPTIMIZATION:  0.6673956513404846
# LOSS AFTER OPTIMIZATION:  0.004148787467454599
# IMPROVEMENT:  0.66324686387303
# Iteration: 165
# 0.7449846267700195
# 0.6866467679055742
# LOSS BEFORE OPTIMIZATION:  0.18820838630199432
# LOSS AFTER OPTIMIZATION:  0.023943968125233205
# IMPROVEMENT:  0.16426441817676113
# Iteration: 166
# 0.8913848400115967
# 0.9258334157079281
# LOSS BEFORE OPTIMIZATION:  0.047600578516721725
# LOSS AFTER OPTIMIZATION:  0.006216297898604037
# IMPROVEMENT:  0.04138428061811769
# Iteration: 167
# 0.6539598107337952
# 0.538440878440519
# LOSS BEFORE OPTIMIZATION:  0.08638137578964233
# LOSS AFTER OPTIMIZATION:  0.0017931631880219185
# IMPROVEMENT:  0.08458821260162042
# Iteration: 168
# 0.8732463121414185
# 0.9072187408838701
# LOSS BEFORE OPTIMIZATION:  0.1990041732788086
# LOSS AFTER OPTIMIZATION:  3.3606019505161647e-07
# IMPROVEMENT:  0.19900383721861353
# Iteration: 169
# 0.8394347429275513
# 0.7757667478989722
# LOSS BEFORE OPTIMIZATION:  0.39477813243865967
# LOSS AFTER OPTIMIZATION:  3.250156030349938e-16
# IMPROVEMENT:  0.39477813243865933
# Iteration: 170
# 0.7489489316940308
# 0.669292508630075
# LOSS BEFORE OPTIMIZATION:  0.21343621611595154
# LOSS AFTER OPTIMIZATION:  0.0001661607410729348
# IMPROVEMENT:  0.21327005537487861
# Iteration: 171
# 0.7825567722320557
# 0.780922308423891
# LOSS BEFORE OPTIMIZATION:  0.4896887540817261
# LOSS AFTER OPTIMIZATION:  0.02708645581642716
# IMPROVEMENT:  0.4626022982652989
# Iteration: 172
# 0.8135082125663757
# 0.9824043944221652
# LOSS BEFORE OPTIMIZATION:  0.10210590064525604
# LOSS AFTER OPTIMIZATION:  6.281279634099509e-16
# IMPROVEMENT:  0.10210590064525542
# Iteration: 173
# 0.7566466331481934
# 0.5463639388351714
# LOSS BEFORE OPTIMIZATION:  1.1519120931625366
# LOSS AFTER OPTIMIZATION:  1.0742349568393155e-14
# IMPROVEMENT:  1.151912093162526
# Iteration: 174
# 0.8351166248321533
# 0.8510669067290589
# LOSS BEFORE OPTIMIZATION:  1.5646138191223145
# LOSS AFTER OPTIMIZATION:  1.6931457834912947e-15
# IMPROVEMENT:  1.5646138191223127
# Iteration: 175
# 0.8007268905639648
# 0.5813872825269667
# LOSS BEFORE OPTIMIZATION:  0.1664058417081833
# LOSS AFTER OPTIMIZATION:  5.352222450026056e-15
# IMPROVEMENT:  0.16640584170817793
# Iteration: 176
# 0.8281749486923218
# 0.8471711951955128
# LOSS BEFORE OPTIMIZATION:  0.030613424256443977
# LOSS AFTER OPTIMIZATION:  0.003596523351007825
# IMPROVEMENT:  0.027016900905436153
# Iteration: 177
# 0.8476486802101135
# 0.7541364487142347
# LOSS BEFORE OPTIMIZATION:  0.7673989534378052
# LOSS AFTER OPTIMIZATION:  0.11854420495498284
# IMPROVEMENT:  0.6488547484828223
# Iteration: 178
# 0.8182326555252075
# 0.9616575716484822
# LOSS BEFORE OPTIMIZATION:  0.36788880825042725
# LOSS AFTER OPTIMIZATION:  0.007971227123437542
# IMPROVEMENT:  0.3599175811269897
# Iteration: 179
# 0.6284029483795166
# 0.6974226634369315
# LOSS BEFORE OPTIMIZATION:  0.09086758643388748
# LOSS AFTER OPTIMIZATION:  0.004584898928536909
# IMPROVEMENT:  0.08628268750535058
# Iteration: 180
# 0.8127972483634949
# 0.9193624009172429
# LOSS BEFORE OPTIMIZATION:  0.8572492599487305
# LOSS AFTER OPTIMIZATION:  5.03175869707537e-14
# IMPROVEMENT:  0.8572492599486802
# Iteration: 181
# 0.6633748412132263
# 0.5548258917203077
# LOSS BEFORE OPTIMIZATION:  0.1741865873336792
# LOSS AFTER OPTIMIZATION:  0.004895567454090574
# IMPROVEMENT:  0.1692910198795886
# Iteration: 182
# 0.7524062991142273
# 0.685411989772488
# LOSS BEFORE OPTIMIZATION:  0.307329386472702
# LOSS AFTER OPTIMIZATION:  0.0026983363838523015
# IMPROVEMENT:  0.3046310500888497
# Iteration: 183
# 0.6679937839508057
# 1.4455805890544906
# LOSS BEFORE OPTIMIZATION:  0.8393760919570923
# LOSS AFTER OPTIMIZATION:  7.210534795955799
# IMPROVEMENT:  -6.371158703998707
# Iteration: 184
# 0.7535499334335327
# 0.9718973877257137
# LOSS BEFORE OPTIMIZATION:  1.738479733467102
# LOSS AFTER OPTIMIZATION:  4.246165249139742e-14
# IMPROVEMENT:  1.7384797334670596
# Iteration: 185
# 0.761033833026886
# 0.892390006114197
# LOSS BEFORE OPTIMIZATION:  0.12447871267795563
# LOSS AFTER OPTIMIZATION:  0.5076465884553522
# IMPROVEMENT:  -0.3831678757773965
# Iteration: 186
# 0.7078315019607544
# 0.7073150472194523
# LOSS BEFORE OPTIMIZATION:  0.48678863048553467
# LOSS AFTER OPTIMIZATION:  0.0032854186875529456
# IMPROVEMENT:  0.4835032117979817
# Iteration: 187
# 0.7515175938606262
# 0.9477632357026747
# LOSS BEFORE OPTIMIZATION:  0.1153084933757782
# LOSS AFTER OPTIMIZATION:  0.003438987580459738
# IMPROVEMENT:  0.11186950579531846
# Iteration: 188
# 0.7822558879852295
# 0.667194427679109
# LOSS BEFORE OPTIMIZATION:  0.1997101753950119
# LOSS AFTER OPTIMIZATION:  3.3450374431182834e-17
# IMPROVEMENT:  0.19971017539501187
# Iteration: 189
# 0.8167442083358765
# 1.0110767858739733
# LOSS BEFORE OPTIMIZATION:  0.17489859461784363
# LOSS AFTER OPTIMIZATION:  0.00031574024580556634
# IMPROVEMENT:  0.17458285437203805
# Iteration: 190
# 0.7998824119567871
# 0.9643445441718395
# LOSS BEFORE OPTIMIZATION:  0.40151458978652954
# LOSS AFTER OPTIMIZATION:  0.20646148226928585
# IMPROVEMENT:  0.1950531075172437
# Iteration: 191
# 0.8557121753692627
# 0.8545692404793248
# LOSS BEFORE OPTIMIZATION:  0.05755729600787163
# LOSS AFTER OPTIMIZATION:  9.905997241778244e-15
# IMPROVEMENT:  0.05755729600786172
# Iteration: 192
# 0.6115909218788147
# 0.5288522764419997
# LOSS BEFORE OPTIMIZATION:  0.022110572084784508
# LOSS AFTER OPTIMIZATION:  3.9449296211593156e-15
# IMPROVEMENT:  0.022110572084780563
# Iteration: 193
# 0.7985063791275024
# 0.8625230684611574
# LOSS BEFORE OPTIMIZATION:  0.5389360785484314
# LOSS AFTER OPTIMIZATION:  0.005961435036023154
# IMPROVEMENT:  0.5329746435124082
# Iteration: 194
# 0.7053025364875793
# 0.5681626070834541
# LOSS BEFORE OPTIMIZATION:  0.08595572412014008
# LOSS AFTER OPTIMIZATION:  0.010286657811432476
# IMPROVEMENT:  0.0756690663087076
# Iteration: 195
# 0.918201208114624
# 0.9334074922693476
# LOSS BEFORE OPTIMIZATION:  0.03132614493370056
# LOSS AFTER OPTIMIZATION:  0.0007977222242627322
# IMPROVEMENT:  0.03052842270943783
# Iteration: 196
# 0.7082328796386719
# 0.7569725668899763
# LOSS BEFORE OPTIMIZATION:  0.15119387209415436
# LOSS AFTER OPTIMIZATION:  0.0002456436055850173
# IMPROVEMENT:  0.15094822848856934
# Iteration: 197
# 0.7820315361022949
# 0.7067507681060311
# LOSS BEFORE OPTIMIZATION:  0.021654276177287102
# LOSS AFTER OPTIMIZATION:  0.008394785438976806
# IMPROVEMENT:  0.013259490738310295
# Iteration: 198
# 0.8004244565963745
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-4af0e945a985> in <module>
#      25     cone = Cone(theta, axis, vertex)
#      26     print(cone.theta)
# ---> 27     cone = cone_fit(points, initial_guess=cone, weights=None)
#      28     try:
#      29         print(cone.theta)
#
# ~/Desktop/programming/phd/SHREC/SHREC2022/cone_fit.py in cone_fit(points, weights, initial_guess)
#      56     #print(initial_guess.theta, initial_guess.axis.shape)
#      57     x0 = np.concatenate([np.array([initial_guess.theta]), initial_guess.axis, initial_guess.vertex])
# ---> 58     results = optimize.least_squares(
#      59         cone_fit_residuals, x0=x0, args=(points, weights), ftol=1e-10
#      60     )
#
# ~/anaconda3/envs/vvrenv/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     923
#     924     elif method == 'trf':
# --> 925         result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     926                      gtol, max_nfev, x_scale, loss_function, tr_solver,
#     927                      tr_options.copy(), verbose)
#
# ~/anaconda3/envs/vvrenv/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     117     # functions are kept the most readable.
#     118     if np.all(lb == -np.inf) and np.all(ub == np.inf):
# --> 119         return trf_no_bounds(
#     120             fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121             loss_function, tr_solver, tr_options, verbose)
#
# ~/anaconda3/envs/vvrenv/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py in trf_no_bounds(fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     497             step = d * step_h
#     498             x_new = x + step
# --> 499             f_new = fun(x_new)
#     500             nfev += 1
#     501
#
# ~/anaconda3/envs/vvrenv/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py in fun_wrapped(x)
#     810
#     811     def fun_wrapped(x):
# --> 812         return np.atleast_1d(fun(x, *args, **kwargs))
#     813
#     814     if method == 'trf':
#
# ~/Desktop/programming/phd/SHREC/SHREC2022/cone_fit.py in cone_fit_residuals(cone_params, points, weights)
#      45     def cone_fit_residuals(cone_params, points, weights):
#      46
# ---> 47         cone = Cone(cone_params[0], cone_params[1:4], cone_params[4:7])
#      48
#      49         distances = cone.distance_to_point(points)
#
# ~/Desktop/programming/phd/SHREC/SHREC2022/cone_fit.py in __init__(self, theta, axis, vertex)
#      21         self.vertex = vertex
#      22         self.axis = axis
# ---> 23         self.theta = theta
#      24
#      25     def __repr__(self):
#
# ~/Desktop/programming/phd/SHREC/geomfitty/geomfitty/_descriptor.py in __set__(self, instance, value)
#      60         value = DTYPE(value)
#      61         if value < 0:
# ---> 62             raise ValueError(
#      63                 "{} must be initialized with a positive number".format(
#      64                     self.__class__.__name__
#
# ValueError: PositiveNumber must be initialized with a positive number

# %%
cone

# %%
from utils import visualize_pointcloud
visualize_pointcloud(sample["initial_points"][0])
